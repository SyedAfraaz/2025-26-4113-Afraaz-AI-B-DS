# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedAfraaz/2025-26-4113-Afraaz-AI-B-DS/blob/main/Week-5/Q22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### DATE : 10/3/26
#
# QUESTION 22

# %%
import math
n=100
x=60
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion:",p_hat)
print("Confidence Interval:",(lower,upper))
p0=0.50
z_test=(p_hat-p0)/math.sqrt(p0*(1-p0)/n)
print("Test Statistic:",z_test)
if abs(z_test)>1.96:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# Sample proportion: 0.6
# Confidence Interval: (0.5039800020828994, 0.6960199979171006)
# Test Statistic: 1.9999999999999996
# Reject null hypothesis
