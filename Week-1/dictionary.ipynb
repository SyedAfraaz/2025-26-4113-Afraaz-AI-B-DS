# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedAfraaz/2025-26-4113-Afraaz-AI-B-DS/blob/main/Week-1/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a dictionary
d = {
    "name":"Syed Afraaz",
    "age":25,
    "course": "Computer Science and AI"
    }
print("Original dictionary:", d)
# Accessing values
print("Name:", d["name"])
print("Age:", d.get("age"))
# Adding a new key-value pair
d["college"] = "XYZ University"
print("After adding:", d)
# Updating value
d["age"] = 21
print("After updating:", d)
# Removing elements
d.pop("course")
print("After pop:", d)
removed_item = d.popitem()
print("After popitem:", d)
print("Removed item:", removed_item)
# Keys, values, items
print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())
# Length
print("Length of dictionary:", len(d))
# Looping through dictionary
print("Looping through keys:")
for key in d:
    print(key, ":", d[key])
print("Looping through key-value pairs:")
for k, v in d.items():
    print(k, "->", v)
# Updating using update()
d.update({"city": "Hyderabad", "age": 22})
print("After update():", d)
student = {
    "info": {
        "marks": 95
    }
}
print("Nested dictionary value:", student["info"]["marks"])
print("Nested dictionary value:", student["info"]["marks"])
# Clearing dictionary
d.clear()
print("After clear:", d)
# Out:
# Original dictionary: {'name': 'Syed Afraaz', 'age': 25, 'course': 'Computer Science and AI'}
# Name: Syed Afraaz
# Age: 25
# After adding: {'name': 'Syed Afraaz', 'age': 25, 'course': 'Computer Science and AI', 'college': 'XYZ University'}
# After updating: {'name': 'Syed Afraaz', 'age': 21, 'course': 'Computer Science and AI', 'college': 'XYZ University'}
# After pop: {'name': 'Syed Afraaz', 'age': 21, 'college': 'XYZ University'}
# After popitem: {'name': 'Syed Afraaz', 'age': 21}
# Removed item: ('college', 'XYZ University')
# Keys: dict_keys(['name', 'age'])
# Values: dict_values(['Syed Afraaz', 21])
# Items: dict_items([('name', 'Syed Afraaz'), ('age', 21)])
# Length of dictionary: 2
# Looping through keys:
# name : Syed Afraaz
# age : 21
# Looping through key-value pairs:
# name -> Syed Afraaz
# age -> 21
# After update(): {'name': 'Syed Afraaz', 'age': 22, 'city': 'Hyderabad'}
# Nested dictionary value: 95
# Nested dictionary value: 95
# After clear: {}
