# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedAfraaz/2025-26-4113-Afraaz-AI-B-DS/blob/main/Week-1/tupleoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (10, 20, 30, 40, 20)
print("Original tuple:", t)

t = (10, 20, 30, 40, 20)
print("First element:", t[0])
print("Last element:", t[-1])

t = (10, 20, 30, 40, 20)
print("Sliced tuple:", t[1:4])

t = (10, 20, 30, 40, 20)
print("Length of tuple:", len(t))

t = (10, 20, 30, 40, 20)
print("Count of 20:", t.count(20))

t = (10, 20, 30, 40, 20)
print("Index of 40:", t.index(40))

t = (10, 20, 30, 40, 20)
print("Tuple elements:")
for item in t:
    print(item)

t = (10, 20, 30, 40, 20)
t2 = (50, 60)
t3 = t + t2
print("After concatenation:", t3)

t = (10, 20, 30, 40, 20)
t4 = t * 2
print("After repetition:", t4)

t = (10, 20, 30, 40, 20)
nested = (1, (2, 3), (4, 5))
print("Nested tuple element:", nested[1][0])
# Out:
# Original tuple: (10, 20, 30, 40, 20)
# First element: 10
# Last element: 20
# Sliced tuple: (20, 30, 40)
# Length of tuple: 5
# Count of 20: 2
# Index of 40: 3
# Tuple elements:
# 10
# 20
# 30
# 40
# 20
# After concatenation: (10, 20, 30, 40, 20, 50, 60)
# After repetition: (10, 20, 30, 40, 20, 10, 20, 30, 40, 20)
# Nested tuple element: 2
