# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedAfraaz/2025-26-4113-Afraaz-AI-B-DS/blob/main/Week-8/Q30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#30)Implement the decision tree for the given dataset
from sklearn.tree import DecisionTreeClassifier
X=[[1,1],[1,0],[0,1],[0,0]]
y=[0,1,1,0]
model=DecisionTreeClassifier()
model.fit(X,y)
print(model.predict([[1,0]]))
# Out:
# [1]
