# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedAfraaz/2025-26-4113-Afraaz-AI-B-DS/blob/main/Week-8/Q27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#27)Implement the confusion matrix for any of the example dataset
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt
y_true = [1,0,1,0,1,0,1,0]
y_pred = [1,1,1,0,0,0,1,0]
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n",cm)
# Out:
# Confusion Matrix:
#  [[3 1]
#  [1 3]]
